# %% [markdown]
# # Collect additional musician data
# We have collected a seed set of musicians from Wikipedia [here](collect_pages_from_wikipedia_by_category.py) and now we seek to expand the list.
#
# Methods:
# - Suggestions from music streaming service, i.e. [Spotify](https://developer.spotify.com/console/get-search-item/).
# - Broad queries to [DBPedia](https://dbpedia.org/sparql), e.g. "all musicians from Colombia".

# %% [markdown]
# ## Music streaming suggestions

# %%
import pandas as pd
spotify_auth_data = pd.read_csv('../../data/culture_metadata/spotify_auth.csv', header=None, index_col=0).loc[:, 1]
spotify_auth_token = spotify_auth_data.loc['auth_token']

# %% [markdown]
# First we need to look up all the musicians' IDs.

# %%
import requests
test_artist = 'shakira'
search_type = 'artist'
search_url = 'https://api.spotify.com/v1/search'
search_result = requests.get(search_url, params={'q' : test_artist, 'type' : search_type}, headers={'authorization' : f'Bearer {spotify_auth_token}'})
print(search_result)
# Out:
# <Response [200]>

# %%
search_result.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=shakira&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#     'followers': {'href': None, 'total': 18151611},
#     'genres': ['colombian pop', 'dance pop', 'latin', 'latin pop', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#     'id': '0EmeFodog0BfCgMzAIvKQp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/234f86923486e8ba3860def8518c01d5054aac1f',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/2577d225adf779981103c8b0dc75f198e4a55f31',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/caa3eae0ede56110b7c4b7694cfb20e754052f9d',
#       'width': 160}],
#     'name': 'Shakira',
#     'popularity': 89,
#     'type': 'artist',
#     'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/18nKUAfNnowoqfqDhwI3X3'},
#     'followers': {'href': None, 'total': 199},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/18nKUAfNnowoqfqDhwI3X3',
#     'id': '18nKUAfNnowoqfqDhwI3X3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9d27a22530fc3db0ad496f883b191636afb94682',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/a2e8e69465fb96cb8664e7b7919f34b18360736c',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/9de90e7fae98fda4873a3c77625b761aa696164c',
#       'width': 160}],
#     'name': 'Shakira Jasmine',
#     'popularity': 28,
#     'type': 'artist',
#     'uri': 'spotify:artist:18nKUAfNnowoqfqDhwI3X3'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3RaPHdbOVsUjPFljce9rEz'},
#     'followers': {'href': None, 'total': 2331},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3RaPHdbOVsUjPFljce9rEz',
#     'id': '3RaPHdbOVsUjPFljce9rEz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/fc78bafbb4c9077925339848e108ffdd324a9413',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/8485da8f775f4719ce0e6823e083d4ca9f3dc1f6',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ebb9585c542b9d47061d2b4ab393d4bc79340f40',
#       'width': 160}],
#     'name': 'Shakira Martínez',
#     'popularity': 21,
#     'type': 'artist',
#     'uri': 'spotify:artist:3RaPHdbOVsUjPFljce9rEz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/12lqF84e1svUbLF8xWB1LY'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/12lqF84e1svUbLF8xWB1LY',
#     'id': '12lqF84e1svUbLF8xWB1LY',
#     'images': [],
#     'name': 'Shakiradebarra',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:12lqF84e1svUbLF8xWB1LY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2WfSfWklOh8zc7hLZioNuJ'},
#     'followers': {'href': None, 'total': 25},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2WfSfWklOh8zc7hLZioNuJ',
#     'id': '2WfSfWklOh8zc7hLZioNuJ',
#     'images': [],
#     'name': 'Shakira Glenn',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2WfSfWklOh8zc7hLZioNuJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/
offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 64}}

# %%
print(search_result.status_code)
# Out:
# 200

# %%
a = search_result.json()['artists']['items']
print(len(a))
# Out:
# 20

# %% [markdown]
# Great! Let's restrict the results to exact name matches and take the most popular result (follower count).

# %%
from unidecode import unidecode
from time import sleep
def clean_txt(txt):
    return unidecode(txt.lower())
def collect_artist_data(artist_name, api, 
#                         search_url='https://api.spotify.com/v1/search', 
                        request_sleep_time=60,
                        artist_keys=['name', 'id', 'genres'],
                        SEARCH_LIMIT=20):
    """
    Collect all artist data from Spotify:
    follower count, genres, ID
    """
    clean_artist_name = clean_txt(artist_name)
    successful_search = False
    while(not successful_search):
        search_result = api.search(q=clean_artist_name, type='artist', limit=SEARCH_LIMIT)
        # TODO: status code
#         search_result = requests.get(search_url, params={'q' : clean_artist_name, 'type' : search_type}, headers={'authorization' : f'Bearer {auth_token}'})
#         sleep(10)
#         if(search_result.status_code == 200):
        successful_search = True
        # filter for name match
        search_result_data = search_result['artists']['items']
        valid_search_result_data = list(filter(lambda x: clean_txt(x['name'])==clean_artist_name, search_result_data))
        if(len(valid_search_result_data) > 0):
            # sort by followers
            valid_search_result_data = list(sorted(valid_search_result_data, key=lambda x: x['followers']['total'], reverse=True))
            # take top result
            matching_search_result = valid_search_result_data[0]
            artist_data = {k : matching_search_result[k] for k in artist_keys}
            artist_data['followers'] = matching_search_result['followers']['total']
        else:
            artist_data = {'name' : clean_artist_name}
#         elif(search_result.status_code == 429):
#             print(f'error, too many requests, sleeping for {request_sleep_time} sec')
#             sleep(request_sleep_time)
    return artist_data
def collect_all_artist_data(artist_names, api):
    artist_data_combined = []
    for artist_name in artist_names:
        print('processing artist %s'%(artist_name))
        artist_data = collect_artist_data(artist_name, api)
        artist_data = pd.Series(artist_data)
        artist_data_combined.append(artist_data)
    artist_data_combined = pd.concat(artist_data_combined, axis=1).transpose()
    return artist_data_combined

# %%
# we are going to use python wrapper for Spotify because otherwise we need to regenerate auth tokens
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy import Spotify
api_creds = SpotifyClientCredentials(client_id=spotify_auth_data.loc['client_id'], client_secret=spotify_auth_data.loc['client_secret'])
api = Spotify(client_credentials_manager=api_creds)

# %%
test_artist = 'shakira'
artist_data = collect_artist_data(test_artist, api)
print(artist_data)
# Out:
# {'name': 'Shakira', 'id': '0EmeFodog0BfCgMzAIvKQp', 'genres': ['colombian pop', 'dance pop', 'latin', 'latin pop', 'pop'], 'followers': 18151611}

# %%
# load wiki data
latin_american_wiki_en_artist_data = pd.read_csv('../../data/culture_metadata/latin_american_pop_musicians_en_wiki_data.tsv', sep='\t', index_col=False)
latin_american_wiki_es_artist_data = pd.read_csv('../../data/culture_metadata/latin_american_pop_musicians_es_wiki_data.tsv', sep='\t', index_col=False)
latin_american_wiki_artist_data = pd.concat([latin_american_wiki_en_artist_data, latin_american_wiki_es_artist_data], axis=0)
# add clean col
latin_american_wiki_artist_data = latin_american_wiki_artist_data.assign(**{
    'clean_name' : latin_american_wiki_artist_data.loc[:, 'name'].apply(clean_txt)
})
# drop duplicates
latin_american_wiki_artist_data.drop_duplicates('clean_name', inplace=True)
display(latin_american_wiki_artist_data.head())
# Out:
#                      name                      wiki_url  \
# 0                Dorismar                /wiki/Dorismar
# 1           Emilia Mernes           /wiki/Emilia_Mernes
# 2           Lali Espósito      /wiki/Lali_Esp%C3%B3sito
# 3  Laura Natalia Esquivel  /wiki/Laura_Natalia_Esquivel
# 4        Valeria Gastaldi        /wiki/Valeria_Gastaldi
#
#            page_category              clean_name
# 0  Argentine_pop_singers                dorismar
# 1  Argentine_pop_singers           emilia mernes
# 2  Argentine_pop_singers           lali esposito
# 3  Argentine_pop_singers  laura natalia esquivel
# 4  Argentine_pop_singers        valeria gastaldi

# %%
## old code: generating auth token
# generate auth token
# client_id = spotify_auth_data.loc['client_id']
# redirect_URI = spotify_auth_data.loc['redirect_URI']
# auth_request_URL = 'https://accounts.spotify.com/authorize'
# auth_request_result = requests.get(auth_request_URL, params={'client_id' : client_id, 'response_type' : 'code', 'redirect_uri' : redirect_URI})
# print(auth_request_result)

# %%
latin_american_artist_clean_names = latin_american_wiki_artist_data.loc[:, 'clean_name'].unique()
latin_american_artist_query_data = collect_all_artist_data(latin_american_artist_clean_names, api)
# Out:
# processing artist dorismar
# processing artist emilia mernes
# processing artist lali esposito
# processing artist laura natalia esquivel
# processing artist valeria gastaldi
# processing artist isol
# processing artist hilda lizarazu
# processing artist marcela morelo
# processing artist emanuel ortega
# processing artist sofia reca
# processing artist violeta rivas
# processing artist benjamin rojas
# processing artist julian serrano
# processing artist silvia suller
# processing artist tormenta
# processing artist diego torres
# processing artist trix
# processing artist maxi trusso
# processing artist sam alves
# processing artist baby do brasil
# processing artist bianca alencar
# processing artist biel
# processing artist lua blanco
# processing artist roberto carlos
# processing artist da lou
# processing artist natalia damini
# processing artist diana
# processing artist felipe dylon
# processing artist marjorie estiano
# processing artist manu gavassi
# processing artist latino
# processing artist tania mara
# processing artist mc sapao
# processing artist luciana mello
# processing artist nego do borel
# processing artist mariana nolasco
# processing artist daniel peixoto
# processing artist perlla
# processing artist pocah
# processing artist luiza possi
# processing artist dh silveira
# processing artist samira winter
# processing artist tati zaqui
# processing artist ximena abarca
# processing artist carmen barros
# processing artist daniela castillo
# processing artist cecilia echenique
# processing artist amaya forch
# processing artist german garmendia
# processing artist myriam hernandez
# processing artist pablo holman
# processing artist k-bust
# processing artist k-reena
# processing artist mon laferte
# processing artist paloma mami
# processing artist javiera mena
# processing artist dj mendez
# processing artist barbara munoz
# processing artist nicole natalino
# processing artist nicole
# processing artist camila silva
# processing artist andrea tessa
# processing artist francisca valenzuela
# processing artist anasol
# processing artist paula arenas
# processing artist lucas arnau
# processing artist camilo
# processing artist andrea echeverri
# processing artist fatiniza
# processing artist fonseca
# processing artist galy galiano
# processing artist dario gomez
# processing artist jc gonzalez
# processing artist ivonne guzman
# processing artist juanes
# processing artist fanny lu
# processing artist maia
# processing artist maluma
# processing artist naela
# processing artist valentina rendon
# processing artist jhonny rivera
# processing artist nina rodriguez
# processing artist samper
# processing artist shakira
# processing artist sara tunes
# processing artist sebastian yatra
# processing artist mirella cesa
# processing artist pamela cortes
# processing artist daniela guzman
# processing artist fausto mino
# processing artist gabriela villalba
# processing artist natalia lafourcade
# processing artist arturo g. alvarez
# processing artist jorge blanco
# processing artist ari borovoy
# processing artist paty cantu
# processing artist cristian castro
# processing artist christian chavez
# processing artist emmanuel
# processing artist alejandro fernandez
# processing artist juan gabriel
# processing artist edith marquez
# processing artist luis miguel
# processing artist manuel mijares
# processing artist marco more
# processing artist belinda peregrin
# processing artist pablo portillo
# processing artist sofia reyes
# processing artist carlos rivera
# processing artist gerardo velazquez
# processing artist ethel afamado
# processing artist max capote
# processing artist jorge drexler
# processing artist natalia oreiro
# processing artist pablo sciuto
# processing artist christina aguilera
# processing artist paulina aguirre
# processing artist anahi
# processing artist anitta
# processing artist marc anthony
# processing artist linda bandry
# processing artist carlos baute
# processing artist lou bega
# processing artist obie bermudez
# processing artist david bisbal
# processing artist wanessa camargo
# processing artist moises canelo
# processing artist pedro capo
# processing artist manuel carrasco
# processing artist cathia
# processing artist chayanne
# processing artist david civera
# processing artist millie corretjer
# processing artist d'manti
# processing artist sergio dalma
# processing artist guillermo davila
# processing artist david demaria
# processing artist daniel diges
# processing artist erika ender
# processing artist gloria estefan
# processing artist jose feliciano
# processing artist fey
# processing artist luis fonsi
# processing artist francinne
# processing artist frankie j
# processing artist raul fuentes cuenca
# processing artist eric fukusaki
# processing artist gale
# processing artist kany garcia
# processing artist odalys garcia
# processing artist gisselle
# processing artist gretchen
# processing artist magos herrera
# processing artist enrique iglesias
# processing artist julio iglesias
# processing artist janid
# processing artist jose jose
# processing artist selena lee canales
# processing artist lucero
# processing artist victor manuelle
# processing artist celia mara
# processing artist ricky martin
# processing artist abraham mateo
# processing artist mau y ricky
# processing artist lisette melendez
# processing artist mike bahia
# processing artist miosoty
# processing artist yolandita monge
# processing artist alejandro montaner
# processing artist ricardo montaner
# processing artist javier monthiel
# processing artist nacho
# processing artist ednita nazario
# processing artist noelia
# processing artist danny ocean
# retrying ...1secs
# processing artist fernando osorio
# processing artist danna paola
# processing artist laura pausini
# processing artist yolanda perez
# processing artist pijuan
# processing artist alexandre pires
# processing artist abraham quintanilla
# processing artist luz rios
# processing artist danny rivera
# processing artist elan luz rivera
# processing artist jerry rivera
# processing artist lourdes robles
# processing artist tono rosario
# processing artist paulina rubio
# processing artist miriam sandler
# processing artist alejandro sanz
# processing artist raquel sofia
# processing artist marco antonio solis
# processing artist tahis
# processing artist olga tanon
# processing artist thalia
# processing artist alvaro torres
# processing artist tommy torres
# processing artist gloria trevi
# processing artist mariana vega
# processing artist anais vivas
# processing artist pee wee
# processing artist xuxa
# processing artist diego alfonso
# processing artist agustin almeyda
# processing artist maria clara alonso
# processing artist christian andrade
# processing artist patricio arellano
# processing artist emilia attias
# processing artist noemi barbero
# processing artist valeria baroni
# processing artist francisco bass
# processing artist florencia bertotti
# processing artist miss bolivia
# processing artist claudia brant
# processing artist walter bruno
# processing artist liliana caldini
# processing artist micaela castelotti
# processing artist chenoa
# processing artist cindy coleoni
# processing artist coco
# processing artist felipe colombo
# processing artist coti
# processing artist mariano d'abbraccio
# processing artist virginia da cunha
# processing artist gaston dalmau
# processing artist maria del cerro
# processing artist alejandro desilvestre
# processing artist pablo dhysan
# processing artist nadia di cello
# processing artist mavi diaz
# processing artist donald
# processing artist marie-claire d'ubaldo
# processing artist alicia escola
# processing artist laura esquivel
# processing artist beto fernan
# processing artist lourdes fernandez
# processing artist sol fernandez
# processing artist nicolas francella
# processing artist facundo gambande
# processing artist juliana gattas
# processing artist giannina giunta
# processing artist fer gril
# processing artist juan manuel guilera
# processing artist dick haymes
# processing artist emmanuel horvilleur
# processing artist louta
# processing artist kevin johansen
# processing artist juan ramon
# processing artist mercedes lambre
# processing artist peter lanzani
# processing artist alejandro lerner
# processing artist luisana lopilato
# processing artist valeria lynch
# processing artist andy macia
# processing artist jorge maggio
# processing artist cris manzano
# processing artist jenny martinez
# processing artist daniel rodrigo martins
# processing artist ruben mattos
# processing artist matias mayer
# processing artist laura miller
# processing artist candelaria molfese
# processing artist juana molina
# processing artist marco montoya
# processing artist carlos morell
# processing artist sergio nacif
# processing artist maria fernanda neil
# processing artist nicki nicole
# processing artist chico novarro
# processing artist rosario ortega
# processing artist agustina palma
# processing artist natalie perez
# processing artist abel pintos
# processing artist lola ponce
# processing artist nono pugliese
# processing artist paolo ragone
# processing artist santiago ramundo
# processing artist geronimo rauch
# processing artist martin ricca
# processing artist nicolas riera
# processing artist rizha
# processing artist juan manuel rodil
# processing artist sol rodriguez
# processing artist rubi
# processing artist claudia ruffinatti
# processing artist pablo ruiz
# processing artist oriana sabatini
# processing artist raul sagan
# processing artist paola sallustro
# processing artist dolores sarmiento
# processing artist belen scalella
# processing artist noel schajris
# processing artist ale sergi
# processing artist eddie sierra
# processing artist blanquita silvan
# processing artist johny tedesco
# processing artist tete
# processing artist tini stoessel
# processing artist twiggy
# processing artist pablo utrera
# processing artist pino valenti
# processing artist lucas velasco
# processing artist lissa vera
# processing artist candela vetrano
# processing artist victoria maurette
# processing artist olivia viggiano
# processing artist florencia villagra
# processing artist jenny williams
# processing artist axel
# processing artist sophia abrahao
# processing artist morris albert
# processing artist micael borges
# processing artist adriana calcanhotto
# processing artist vanessa da mata
# processing artist zelia duncan
# processing artist liah
# processing artist jullie
# processing artist kelly key
# processing artist mariana lessa
# processing artist lexa
# processing artist yasmin lucas
# processing artist lucas lucco
# processing artist luka
# processing artist milton nascimento
# processing artist samuel nascimento
# processing artist alexandre nero
# processing artist jair rodrigues
# processing artist sandy
# retrying ...3secs
# processing artist luan santana
# processing artist wanessa
# processing artist terry winter
# processing artist nea agostini
# processing artist cecilia aguayo
# processing artist vanessa aguilera
# processing artist daniela aleuy
# processing artist andrei hadler
# processing artist alex anwandter
# processing artist rosamel araya
# processing artist carlos azocar
# processing artist carolina bezamat
# processing artist catalina bono
# processing artist raquel calderon
# processing artist benito cerati
# processing artist christell
# processing artist maria colores
# processing artist paz court
# processing artist koko
# processing artist beto cuevas
# processing artist gepe
# processing artist rene de la vega
# processing artist denise rosenthal
# processing artist luciana echeverria
# processing artist el viaje de seth
# processing artist gabriela ernst
# processing artist giovanni falchetti
# processing artist cami
# processing artist manuel gatti
# processing artist francisco gormaz
# processing artist mario guerrero
# processing artist marcelo hernandez
# processing artist paula herrera
# processing artist juan antonio labra
# processing artist sergio lagos
# processing artist andres de leon
# processing artist ariel levy
# processing artist denisse malebran
# processing artist leandro martinez
# processing artist magdalena matthey
# processing artist carolina mestrovic
# processing artist miguelo
# processing artist camila moreno
# processing artist florcita motuda
# processing artist victoria mus
# processing artist natalia molina
# processing artist carolina nissen
# processing artist katherine orellana
# processing artist catalina palacios
# processing artist pali
# processing artist karen bejarano
# processing artist javiera parra
# processing artist luis pedraza
# processing artist pedropiedra
# processing artist princesa alba
# processing artist jeannette pualuan
# processing artist leo quinteros
# processing artist celine reymond
# processing artist johanna rezzio
# processing artist buddy richard
# processing artist monik
# processing artist camilo a secas
# processing artist alvaro scaramelli
# processing artist sebastian silva
# processing artist carolina soto munoz
# processing artist eduardo valenzuela
# processing artist joe vasconcellos
# processing artist karla vasquez
# processing artist kevz
# processing artist eduardo waghorn
# processing artist stanley weissohn
# processing artist diana angel
# processing artist naty botero
# processing artist adriana bottina
# processing artist ryan cabrera
# processing artist santiago cruz
# processing artist dragonfly
# processing artist elia y elizabeth
# processing artist elsa riveros
# processing artist yina gallego
# processing artist manuela gonzalez
# processing artist ilona
# processing artist jerau
# processing artist joal
# processing artist marala
# processing artist marbelle
# processing artist marre
# processing artist isa mosquera
# processing artist mauricio paez
# processing artist david palmer
# processing artist rakel
# processing artist greeicy rendon
# processing artist felipe santos
# processing artist soraya
# processing artist juan pablo vega
# processing artist jorge villamizar
# processing artist xiomara xibille
# processing artist sebastian yepes
# processing artist franco iglesias
# processing artist rudy perez
# processing artist daniela carpio
# processing artist shery
# processing artist asaid
# processing artist ashley grace
# processing artist belinda
# processing artist diego boneta
# processing artist camila fernandez
# processing artist cristobal orellana
# processing artist dulce maria
# processing artist natasha dupeyron
# processing artist ana gabriel
# processing artist eiza gonzalez
# processing artist roger gonzalez
# processing artist paulina goto
# processing artist denisse guerrero
# processing artist denise gutierrez
# processing artist hanna nicole
# processing artist hermanos villalobos
# processing artist paulina holguin
# processing artist jack duarte
# processing artist jesse huerta
# processing artist joy huerta
# processing artist julissa
# processing artist imanol landeta
# processing artist litzy
# processing artist melissa
# processing artist lynda
# processing artist mariana magana
# processing artist maria karunna
# processing artist diana mariscal
# processing artist carla mauri
# processing artist miguel cantalapiedra
# processing artist paulino monroy
# processing artist myriam montemayor
# processing artist regina murguia
# processing artist iraida noriega
# processing artist maite perroni
# processing artist anahi puente
# processing artist selena
# processing artist jose riaza
# processing artist jenni rivera
# processing artist jose luis roma
# processing artist raul roma
# processing artist samo
# processing artist alondra santos
# processing artist america sierra
# processing artist paty sirvent
# processing artist amiel
# processing artist christopher uckermann
# processing artist jerry velazquez
# processing artist julieta venegas
# processing artist alicia villarreal
# processing artist yahir
# processing artist yuri
# processing artist yuridia
# processing artist zoe chamberlain
# processing artist alejandro slay
# processing artist anna carina
# processing artist fiorella cayo
# processing artist caroline cruz valencia
# processing artist gian marco
# processing artist miki gonzalez
# processing artist mayra goni
# processing artist manolo hidalgo
# processing artist christian meier
# processing artist mia mont
# processing artist betty missiego
# processing artist jorge pardo
# processing artist raul romero
# processing artist leslie shaw
# processing artist jean paul strauss
# processing artist susan ochoa
# processing artist raquel amparo
# processing artist anais
# processing artist issa gadala
# processing artist javier grullon
# processing artist lize santana
# processing artist amelia vega
# processing artist jorge aguilar
# processing artist marita capote
# processing artist ricardo de sousa
# processing artist franco de vita
# processing artist paola galue
# processing artist mayre martinez
# processing artist mau & ricky
# processing artist melissa griffiths
# processing artist trino mora
# processing artist tina more
# processing artist mr. pauer
# processing artist florentino primera
# processing artist servando primera
# processing artist elisa rego
# processing artist sheryl rubio
# processing artist marger sealey
# processing artist corina smith
# processing artist vanessa suarez
# processing artist ulises hadjis
# /hg190/istewart6/miniconda3/envs/loanword_adoption/lib/python3.7/site-packages/ipykernel_launcher.py:46: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
import numpy as np
latin_american_artist_query_data = latin_american_artist_query_data.assign(**{
    'clean_name' : latin_american_artist_query_data.loc[:, 'name'].apply(lambda x: clean_txt(x))
})
valid_latin_american_artist_query_data = latin_american_artist_query_data[~latin_american_artist_query_data.loc[:, 'id'].apply(lambda x: type(x) is float and np.isnan(x))]
print('%d/%d valid queries'%(valid_latin_american_artist_query_data.shape[0], latin_american_artist_query_data.shape[0]))
# Out:
# 424/526 valid queries

# %%
display(valid_latin_american_artist_query_data[valid_latin_american_artist_query_data.loc[:, 'clean_name']=='shakira'].head())
# Out:
#    followers                                             genres  \
# 83  18151611  [colombian pop, dance pop, latin, latin pop, pop]
#
#                         id     name clean_name
# 83  0EmeFodog0BfCgMzAIvKQp  Shakira    shakira

# %% [markdown]
# OK! Now that we have the IDs, let's look for similar artists.

# %%
def get_similar_artists(artist_id, api, artist_keys=['name', 'id', 'genres'],):
    similar_artist_data_response = api.artist_related_artists(artist_id)
    similar_artists = similar_artist_data_response['artists']
    similar_artist_data_combined = []
    for similar_artist in similar_artists:
        artist_data = {k : similar_artist[k] for k in artist_keys}
        artist_data['followers'] = similar_artist['followers']['total']
        similar_artist_data_combined.append(pd.Series(artist_data))
    if(len(similar_artist_data_combined) > 0):
        similar_artist_data_combined = pd.concat(similar_artist_data_combined, axis=1).transpose()
    return similar_artist_data_combined
def get_similar_artists_all_ids(artist_ids, api):
    similar_artist_data_combined = []
    for artist_id in artist_ids:
        print('processing ID %s'%(artist_id))
        similar_artist_data = get_similar_artists(artist_id, api)
        if(len(similar_artist_data) > 0):
            similar_artist_data = similar_artist_data.assign(**{
                'similar_artist_query_id' : artist_id,
            })
            similar_artist_data_combined.append(similar_artist_data)
    similar_artist_data_combined = pd.concat(similar_artist_data_combined, axis=0)
    return similar_artist_data_combined

# %%
test_id = '0EmeFodog0BfCgMzAIvKQp'
a = get_similar_artists(test_id, api)
display(a.head())
# Out:
#             name                      id  \
# 0  Paulina Rubio  1d6dwipPrsFSJVmFTTdFSS
# 1         Thalía  23wEWD21D4TPYiJugoXmYb
# 2        Belinda  5LeiVcEnsZcwc133TUhJNW
# 3       Belanova  3oNy8cjBtJzLC07I70sklp
# 4   Gloria Trevi  1Db5GsIoVWYktPoD2nnPZZ
#
#                                               genres followers
# 0  [dance pop, latin, latin arena pop, latin pop,...   1481320
# 1         [dance pop, latin, latin pop, mexican pop]   2385202
# 2  [dance pop, latin, latin arena pop, latin pop,...    711735
# 3  [dance pop, latin, latin alternative, latin ar...    564632
# 4   [latin, latin arena pop, latin pop, mexican pop]   1743462

# %%
a[~a.loc[:, 'id'].isin(valid_latin_american_artist_ids)]
# Out:
#                   name                      id  \
# 3             Belanova  3oNy8cjBtJzLC07I70sklp
# 10                 OV7  5zaT4Qu9otu6z4oyWjRqM2
# 11    Alejandra Guzman  7Hf9AwMO37bSdxHb0FBGmO
# 12         Playa Limbo  6XmHtVhgpE33VHFEp2V1P8
# 13  La Quinta Estacion  7FZj349hdLfD6qzXkJLuAh
# 15               Kabah  61hAcjvvUS6EXMpeeHwaDi
# 16         Jesse & Joy  1mX1TWKpNxDSAH16LgDfiR
# 17        Aleks Syntek  0r8toju2ecKaVtItkzAnNi
# 18              Ha*Ash  5xd2Tg7Zo8755eCy8Gxkp8
# 19         Miguel Bosé  7mWCSSOYqm4E9mB7V4ot6S
#
#                                                genres followers
# 3   [dance pop, latin, latin alternative, latin ar...    564632
# 10  [dance pop, grupera, latin, latin arena pop, l...    765380
# 11  [grupera, latin, latin arena pop, latin pop, m...   1760414
# 12  [dance pop, grupera, latin, latin arena pop, l...   1012881
# 13  [latin, latin arena pop, latin pop, pop, rock ...   1395141
# 15  [dance pop, grupera, latin, latin pop, mexican...    430941
# 16  [latin, latin arena pop, latin pop, mexican po...   3311158
# 17  [latin, latin alternative, latin arena pop, la...    719825
# 18   [latin, latin arena pop, latin pop, mexican pop]   3865398
# 19  [latin, latin pop, mexican pop, rock en espano...   1156090

# %%
valid_latin_american_artist_ids = valid_latin_american_artist_query_data.loc[:, 'id'].unique()
latin_american_similar_artists = get_similar_artists_all_ids(valid_latin_american_artist_ids, api)
# Out:
# processing ID 1O3jQItsBlBvLYmCmYfaIQ
# processing ID 1imu37uW2KnEiLMAKmQVgn
# processing ID 63xFjf6Ww22O5gHrBP79G9
# processing ID 1DbNO9pwS4AzYbWX367Pvg
# processing ID 3MRKKlBIXnTcwCoyeCqL6X
# processing ID 37wvb2slf0x1R2W9xIUsWw
# processing ID 3uJCc4nUdN85RXQd464mSR
# processing ID 4FOiEKPQZ60hzEXm0Vgyg3
# processing ID 5IxyAzEThg31lxtUWCcb2q
# processing ID 0LALueHEQunQ2d61fXGeZh
# processing ID 6n5eDbbT3ErAGFipwc9DEg
# processing ID 1V7tGmh5DDSNE0VsUcorJL
# processing ID 6GGy7nQ4GbJ7s6u2W94hgY
# processing ID 2K5llYyoLmzpOcbVuOY1ls
# processing ID 0ifCMWK5i03zLZL2N5hmWy
# processing ID 1JKrt7a4sLz6t0cYXBaTxB
# processing ID 2wIGECcEHN8D4jK2iTma9d
# processing ID 3OgfCHk8YwaZ7NjQHbL4f3
# processing ID 49WIvZvQmpwkFDggpQGRV4
# processing ID 160HajXHxdQFEbwdvDaunP
# processing ID 3Br8ViqqEk8savmROcxWtp
# processing ID 2yq45hmgK51n6g6oM1AH5f
# processing ID 3bAPo06XsUX6fo8iHYUqH7
# processing ID 1ww2z9bVWMR1jjVJWpNM9e
# processing ID 2LZ3j9FcPvimsXU44QgBWW
# processing ID 0DG1OvkrgTy3tr8mTYwlJd
# processing ID 6uwKWDKLDlM0PXvXQ97sRT
# processing ID 3nCgMYjLRax6VXMlZUIYkJ
# processing ID 3ty06GGaglPGYQuGT3tZxz
# processing ID 6mCNsBn9LVMKJE8JnJIR4X
# processing ID 3MKiefPwgGSMd6ylqKVU3n
# processing ID 4NEYQeEYBUjfaXgDQGvFvu
# processing ID 4GT2yrPRxsI2Ij0Ex39fTd
# processing ID 2vvUHogdcbFyljTnQnNqnG
# processing ID 6X0gXc0CpauCS8tvJCfUFE
# processing ID 55xnRKAGGekng6issoIFNl
# processing ID 0yYKXWJ4TLMKfx4UugL8dJ
# processing ID 6BZ1uOhflrZg3CfS2BaJ8l
# processing ID 4O30ZEkMAd0Xn9dc7QC0qT
# processing ID 5NL8vXruD5pEcZXivd9QXF
# processing ID 3kNkESQyliZecPQQ2XgdTo
# processing ID 7mXfsy3lF4kU0f2KTNKSr8
# processing ID 7qhGBgeoqQrOxbZJyBUBzk
# processing ID 5Udwg8yiCTj2zTRt8zKRWH

# %%
unique_latin_american_similar_artist_data = latin_american_similar_artists.drop_duplicates('id', inplace=False)
print('%d/%d unique similar artists'%(unique_latin_american_similar_artist_data.shape[0], latin_american_similar_artists.shape[0]))
# check overlap with original data
new_unique_latin_american_similar_artist_data = unique_latin_american_similar_artist_data[~unique_latin_american_similar_artist_data.loc[:, 'id'].isin(valid_latin_american_artist_ids)]
print('%d/%d new IDs'%(new_unique_latin_american_similar_artist_data.shape[0], unique_latin_american_similar_artist_data.shape[0]))
# Out:
# 3703/7336 unique similar artists
# 3478/3703 new IDs

# %% [markdown]
# Great! Better coverage now. Let's see the genre distribution.

# %%
from functools import reduce
similar_artist_genres = list(reduce(lambda x,y: x+y, new_unique_latin_american_similar_artist_data.loc[:, 'genres'].values))
similar_artist_genre_counts = pd.Series(similar_artist_genres).value_counts()
display(similar_artist_genre_counts.head(20))
# Out:
# latin pop            194
# latin                190
# latin rock           144
# rock en espanol      127
# nueva cancion        114
# tropical             109
# mpb                  107
# latin alternative     99
# chilean rock          97
# pagode                93
# grupera               89
# pop reggaeton         88
# baile pop             86
# argentine rock        84
# chilean indie         81
# pop romantico         78
# rock nacional         77
# funk carioca          76
# spanish pop           74
# argentine indie       70
# dtype: int64

# %% [markdown]
# OK! This is a good sign. Most of the new artists that we've discovered have more Latin American genres.
